# %% [markdown]
# <a href="https://colab.research.google.com/github/pranayreddy713/Alfido-Tech/blob/main/Untitled15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv("/content/globalterrorismdb_0718dist.csv",encoding =('ISO-8859-1'),low_memory =False)

# %%
df.rename(columns={'iyear':'Year','imonth':'Month','iday':'Day','country_txt':'Country','region_txt':'Region','attacktype1_txt':'AttackType','target1':'Target','nkill':'Killed','nwound':'Wounded','summary':'Summary','gname':'Group','targtype1_txt':'Target_type','weaptype1_txt':'Weapon_type','motive':'Motive'},inplace=True)

# %%
df=df[['Year','Month','Day','Country','Region','city','latitude','longitude','AttackType','Killed','Wounded','Target','Summary','Group','Target_type','Weapon_type','Motive']]

# %%
df['casualities']=df['Killed']+df['Wounded']

# %%
df.head(3)
# Out:
#    Year  Month  Day             Country                       Region  \
# 0  1970      7    2  Dominican Republic  Central America & Caribbean
# 1  1970      0    0              Mexico                North America
# 2  1970      1    0         Philippines               Southeast Asia
#
#             city   latitude   longitude                   AttackType  Killed  \
# 0  Santo Domingo  18.456792  -69.951164                Assassination     1.0
# 1    Mexico city  19.371887  -99.086624  Hostage Taking (Kidnapping)     0.0
# 2        Unknown  15.478598  120.599741                Assassination     1.0
#
#    Wounded                   Target Summary  \
# 0      0.0             Julio Guzman     NaN
# 1      0.0  Nadine Chaval, daughter     NaN
# 2      0.0                 Employee     NaN
#
#                                 Group                  Target_type  \
# 0                              MANO-D  Private Citizens & Property
# 1  23rd of September Communist League      Government (Diplomatic)
# 2                             Unknown          Journalists & Media
#
#   Weapon_type Motive  casualities
# 0     Unknown    NaN          1.0
# 1     Unknown    NaN          0.0
# 2     Unknown    NaN          1.0

# %%
df.tail(10)
# Out:
#         Year  Month  Day       Country                      Region  \
# 103317  2011     10    3          Iraq  Middle East & North Africa
# 103318  2011     10    3       Nigeria          Sub-Saharan Africa
# 103319  2011     10    3        Israel  Middle East & North Africa
# 103320  2011     10    3        Russia              Eastern Europe
# 103321  2011     10    3   Afghanistan                  South Asia
# 103322  2011     10    3         India                  South Asia
# 103323  2011     10    3  Saudi Arabia  Middle East & North Africa
# 103324  2011     10    3      Pakistan                  South Asia
# 103325  2011     10    3   Philippines              Southeast Asia
# 103326  2011     10    3   Philippines              Southeast Asia
#
#                     city   latitude   longitude  \
# 103317            Mafriq  33.773349   45.149450
# 103318         Maiduguri  11.840929   13.141459
# 103319   Tuba Zangariyye  32.966008   35.592059
# 103320        El'Khotovo  43.333333   44.200000
# 103321          Kandahar  31.631083   65.742226
# 103322  Latehar district  23.744186   84.504429
# 103323          Awamiyya  26.587351   49.984146
# 103324           Khuzdar  27.809921   66.620956
# 103325            Claver   9.572500  125.733060
# 103326          Taganito   9.539867  125.812852
#
#                             AttackType  Killed  Wounded  \
# 103317               Bombing/Explosion     0.0      3.0
# 103318                   Armed Assault     2.0      0.0
# 103319  Facility/Infrastructure Attack     0.0      0.0
# 103320               Bombing/Explosion     0.0      0.0
# 103321               Bombing/Explosion     3.0     17.0
# 103322                         Unknown     1.0      0.0
# 103323  Facility/Infrastructure Attack     0.0     14.0
# 103324                   Armed Assault     1.0      1.0
# 103325                   Armed Assault     3.0      0.0
# 103326                         Unknown     NaN      NaN
#
#                                                    Target  \
# 103317  An off duty police officer was targeted in the...
# 103318           A tea seller was targeted in the attack.
# 103319                                           A mosque
# 103320               A mosque was targeted in the attack.
# 103321      The Minister for Tribal and Frontiers Affairs
# 103322                     A civilian named Santosh Yadav
# 103323  The security forces were the target of the att...
# 103324                                   A school teacher
# 103325                        Taganito Mining Corporation
# 103326                                                NaN
#
#                                                   Summary  \
# 103317  10/03/2011: On Monday, in Al Mafriq, Diyala, I...
# 103318  10/03/2011: On Monday morning, in Maiduguri, B...
# 103319  10/03/2011: On Monday, in the Tuba Zangaria vi...
# 103320  10/03/2011: On Monday evening, in the Elkhotov...
# 103321  10/03/2011: On Monday morning, in Kandahar, Ka...
# 103322  10/03/2011: On Monday, in Latehar, Jharkhand, ...
# 103323  10/03/2011: On Monday, in Awamiyya, Qatif, Sau...
# 103324  10/03/2011: On Monday, in Khuzdar, Balochistan...
# 103325  10/03/2011: On Monday morning at 1030, in one ...
# 103326  10/03/2011: On Monday afternoon at 1230, in on...
#
#                                                  Group  \
# 103317                                         Unknown
# 103318                                      Boko Haram
# 103319                                         Unknown
# 103320                                         Unknown
# 103321                                         Unknown
# 103322  Communist Party of India - Maoist (CPI-Maoist)
# 103323                                         Unknown
# 103324                                         Unknown
# 103325                         New People's Army (NPA)
# 103326                                             NaN
#
#                            Target_type Weapon_type  \
# 103317                          Police  Explosives
# 103318     Private Citizens & Property    Firearms
# 103319  Religious Figures/Institutions  Incendiary
# 103320  Religious Figures/Institutions  Explosives
# 103321            Government (General)  Explosives
# 103322     Private Citizens & Property     Unknown
# 103323                        Military  Incendiary
# 103324         Educational Institution    Firearms
# 103325                        Business  Incendiary
# 103326                           Busin         NaN
#
#                                                    Motive  casualities
# 103317     The specific motive for the attack is unknown.          3.0
# 103318     The specific motive for the attack is unknown.          2.0
# 103319     The specific motive for the attack is unknown.          0.0
# 103320     The specific motive for the attack is unknown.          0.0
# 103321     The specific motive for the attack is unknown.         20.0
# 103322  The specific motive for the attack was to puni...          1.0
# 103323     The specific motive for the attack is unknown.         14.0
# 103324     The specific motive for the attack is unknown.          2.0
# 103325     The specific motive for the attack is unknown.          3.0
# 103326                                                NaN          NaN

# %%
shape = df.shape

print('Number of columns :', len(df.columns))
print("--------------------------")
df_list = list(df)
print("Total columns present in dataset",df.columns)
print("--------------------------")
print("shape of Dataset",df.shape)
# Out:
# Number of columns : 18
# --------------------------
# Total columns present in dataset Index(['Year', 'Month', 'Day', 'Country', 'Region', 'city', 'latitude',
#        'longitude', 'AttackType', 'Killed', 'Wounded', 'Target', 'Summary',
#        'Group', 'Target_type', 'Weapon_type', 'Motive', 'casualities'],
#       dtype='object')
# --------------------------
# shape of Dataset (103327, 18)

# %%
df.info
# Out:
# <bound method DataFrame.info of         Year  Month  Day             Country                       Region  \
# 0       1970      7    2  Dominican Republic  Central America & Caribbean
# 1       1970      0    0              Mexico                North America
# 2       1970      1    0         Philippines               Southeast Asia
# 3       1970      1    0              Greece               Western Europe
# 4       1970      1    0               Japan                    East Asia
# ...      ...    ...  ...                 ...                          ...
# 103322  2011     10    3               India                   South Asia
# 103323  2011     10    3        Saudi Arabia   Middle East & North Africa
# 103324  2011     10    3            Pakistan                   South Asia
# 103325  2011     10    3         Philippines               Southeast Asia
# 103326  2011     10    3         Philippines               Southeast Asia
#
#                     city   latitude   longitude  \
# 0          Santo Domingo  18.456792  -69.951164
# 1            Mexico city  19.371887  -99.086624
# 2                Unknown  15.478598  120.599741
# 3                 Athens  37.997490   23.762728
# 4                Fukouka  33.580412  130.396361
# ...                  ...        ...         ...
# 103322  Latehar district  23.744186   84.504429
# 103323          Awamiyya  26.587351   49.984146
# 103324           Khuzdar  27.809921   66.620956
# 103325            Claver   9.572500  125.733060
# 103326          Taganito   9.539867  125.812852
#
#                             AttackType  Killed  Wounded  \
# 0                        Assassination     1.0      0.0
# 1          Hostage Taking (Kidnapping)     0.0      0.0
# 2                        Assassination     1.0      0.0
# 3                    Bombing/Explosion     NaN      NaN
# 4       Facility/Infrastructure Attack     NaN      NaN
# ...                                ...     ...      ...
# 103322                         Unknown     1.0      0.0
# 103323  Facility/Infrastructure Attack     0.0     14.0
# 103324                   Armed Assault     1.0      1.0
# 103325                   Armed Assault     3.0      0.0
# 103326                         Unknown     NaN      NaN
#
#                                                    Target  \
# 0                                            Julio Guzman
# 1                                 Nadine Chaval, daughter
# 2                                                Employee
# 3                                            U.S. Embassy
# 4                                          U.S. Consulate
# ...                                                   ...
# 103322                     A civilian named Santosh Yadav
# 103323  The security forces were the target of the att...
# 103324                                   A school teacher
# 103325                        Taganito Mining Corporation
# 103326                                                NaN
#
#                                                   Summary  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 103322  10/03/2011: On Monday, in Latehar, Jharkhand, ...
# 103323  10/03/2011: On Monday, in Awamiyya, Qatif, Sau...
# 103324  10/03/2011: On Monday, in Khuzdar, Balochistan...
# 103325  10/03/2011: On Monday morning at 1030, in one ...
# 103326  10/03/2011: On Monday afternoon at 1230, in on...
#
#                                                  Group  \
# 0                                               MANO-D
# 1                   23rd of September Communist League
# 2                                              Unknown
# 3                                              Unknown
# 4                                              Unknown
# ...                                                ...
# 103322  Communist Party of India - Maoist (CPI-Maoist)
# 103323                                         Unknown
# 103324                                         Unknown
# 103325                         New People's Army (NPA)
# 103326                                             NaN
#
#                         Target_type Weapon_type  \
# 0       Private Citizens & Property     Unknown
# 1           Government (Diplomatic)     Unknown
# 2               Journalists & Media     Unknown
# 3           Government (Diplomatic)  Explosives
# 4           Government (Diplomatic)  Incendiary
# ...                             ...         ...
# 103322  Private Citizens & Property     Unknown
# 103323                     Military  Incendiary
# 103324      Educational Institution    Firearms
# 103325                     Business  Incendiary
# 103326                        Busin         NaN
#
#                                                    Motive  casualities
# 0                                                     NaN          1.0
# 1                                                     NaN          0.0
# 2                                                     NaN          1.0
# 3                                                     NaN          NaN
# 4                                                     NaN          NaN
# ...                                                   ...          ...
# 103322  The specific motive for the attack was to puni...          1.0
# 103323     The specific motive for the attack is unknown.         14.0
# 103324     The specific motive for the attack is unknown.          2.0
# 103325     The specific motive for the attack is unknown.          3.0
# 103326                                                NaN          NaN
#
# [103327 rows x 18 columns]>

# %%
df.skew
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.skew of         Year  Month  Day             Country                       Region  \
# 0       1970      7    2  Dominican Republic  Central America & Caribbean
# 1       1970      0    0              Mexico                North America
# 2       1970      1    0         Philippines               Southeast Asia
# 3       1970      1    0              Greece               Western Europe
# 4       1970      1    0               Japan                    East Asia
# ...      ...    ...  ...                 ...                          ...
# 103322  2011     10    3               India                   South Asia
# 103323  2011     10    3        Saudi Arabia   Middle East & North Africa
# 103324  2011     10    3            Pakistan                   South Asia
# 103325  2011     10    3         Philippines               Southeast Asia
# 103326  2011     10    3         Philippines               Southeast Asia
#
#                     city   latitude   longitude  \
# 0          Santo Domingo  18.456792  -69.951164
# 1            Mexico city  19.371887  -99.086624
# 2                Unknown  15.478598  120.599741
# 3                 Athens  37.997490   23.762728
# 4                Fukouka  33.580412  130.396361
# ...                  ...        ...         ...
# 103322  Latehar district  23.744186   84.504429
# 103323          Awamiyya  26.587351   49.984146
# 103324           Khuzdar  27.809921   66.620956
# 103325            Claver   9.572500  125.733060
# 103326          Taganito   9.539867  125.812852
#
#                             AttackType  Killed  Wounded  \
# 0                        Assassination     1.0      0.0
# 1          Hostage Taking (Kidnapping)     0.0      0.0
# 2                        Assassination     1.0      0.0
# 3                    Bombing/Explosion     NaN      NaN
# 4       Facility/Infrastructure Attack     NaN      NaN
# ...                                ...     ...      ...
# 103322                         Unknown     1.0      0.0
# 103323  Facility/Infrastructure Attack     0.0     14.0
# 103324                   Armed Assault     1.0      1.0
# 103325                   Armed Assault     3.0      0.0
# 103326                         Unknown     NaN      NaN
#
#                                                    Target  \
# 0                                            Julio Guzman
# 1                                 Nadine Chaval, daughter
# 2                                                Employee
# 3                                            U.S. Embassy
# 4                                          U.S. Consulate
# ...                                                   ...
# 103322                     A civilian named Santosh Yadav
# 103323  The security forces were the target of the att...
# 103324                                   A school teacher
# 103325                        Taganito Mining Corporation
# 103326                                                NaN
#
#                                                   Summary  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 103322  10/03/2011: On Monday, in Latehar, Jharkhand, ...
# 103323  10/03/2011: On Monday, in Awamiyya, Qatif, Sau...
# 103324  10/03/2011: On Monday, in Khuzdar, Balochistan...
# 103325  10/03/2011: On Monday morning at 1030, in one ...
# 103326  10/03/2011: On Monday afternoon at 1230, in on...
#
#                                                  Group  \
# 0                                               MANO-D
# 1                   23rd of September Communist League
# 2                                              Unknown
# 3                                              Unknown
# 4                                              Unknown
# ...                                                ...
# 103322  Communist Party of India - Maoist (CPI-Maoist)
# 103323                                         Unknown
# 103324                                         Unknown
# 103325                         New People's Army (NPA)
# 103326                                             NaN
#
#                         Target_type Weapon_type  \
# 0       Private Citizens & Property     Unknown
# 1           Government (Diplomatic)     Unknown
# 2               Journalists & Media     Unknown
# 3           Government (Diplomatic)  Explosives
# 4           Government (Diplomatic)  Incendiary
# ...                             ...         ...
# 103322  Private Citizens & Property     Unknown
# 103323                     Military  Incendiary
# 103324      Educational Institution    Firearms
# 103325                     Business  Incendiary
# 103326                        Busin         NaN
#
#                                                    Motive  casualities
# 0                                                     NaN          1.0
# 1                                                     NaN          0.0
# 2                                                     NaN          1.0
# 3                                                     NaN          NaN
# 4                                                     NaN          NaN
# ...                                                   ...          ...
# 103322  The specific motive for the attack was to puni...          1.0
# 103323     The specific motive for the attack is unknown.         14.0
# 103324     The specific motive for the attack is unknown.          2.0
# 103325     The specific motive for the attack is unknown.          3.0
# 103326                                                NaN          NaN
#
# [103327 rows x 18 columns]>

# %%
df.dtypes
# Out:
# Year             int64
# Month            int64
# Day              int64
# Country         object
# Region          object
# city            object
# latitude       float64
# longitude      float64
# AttackType      object
# Killed         float64
# Wounded        float64
# Target          object
# Summary         object
# Group           object
# Target_type     object
# Weapon_type     object
# Motive          object
# casualities    float64
# dtype: object

# %%
print("Total number of duplicate values found :- ", df.duplicated().sum())
print("Total number of NULL values found :- ", df.isnull().sum())
# Out:
# Total number of duplicate values found :-  7289
# Total number of NULL values found :-  Year               0
# Month              0
# Day                0
# Country            0
# Region             0
# city             430
# latitude        4057
# longitude       4058
# AttackType         0
# Killed          6516
# Wounded         9859
# Target           617
# Summary        66129
# Group              1
# Target_type        0
# Weapon_type        1
# Motive         66680
# casualities    10152
# dtype: int64

# %%
df.describe()
# Out:
#                 Year          Month            Day      latitude  \
# count  103327.000000  103327.000000  103327.000000  99270.000000
# mean     1993.621996       6.424100      15.324572     21.277943
# std        10.892904       3.366051       8.818365     21.680424
# min      1970.000000       0.000000       0.000000    -53.154613
# 25%      1985.000000       4.000000       8.000000      7.199509
# 50%      1992.000000       6.000000      15.000000     27.312840
# 75%      2005.000000       9.000000      23.000000     36.354145
# max      2011.000000      12.000000      31.000000     74.633553
#
#           longitude        Killed       Wounded   casualities
# count  9.926900e+04  96811.000000  93468.000000  93175.000000
# mean  -8.591343e+02      2.347688      3.280781      5.481803
# std    2.735454e+05     11.597495     46.598459     54.017828
# min   -8.618590e+07      0.000000      0.000000      0.000000
# 25%   -7.161225e+01      0.000000      0.000000      0.000000
# 50%    2.410429e+01      0.000000      0.000000      1.000000
# 75%    6.605000e+01      1.000000      1.000000      3.000000
# max    1.793667e+02   1384.000000   8191.000000   9574.000000

# %%
df=df[['Year','Country','Region','city','AttackType','Target_type','Group','Killed']]
df.head()
# Out:
#    Year             Country                       Region           city  \
# 0  1970  Dominican Republic  Central America & Caribbean  Santo Domingo
# 1  1970              Mexico                North America    Mexico city
# 2  1970         Philippines               Southeast Asia        Unknown
# 3  1970              Greece               Western Europe         Athens
# 4  1970               Japan                    East Asia        Fukouka
#
#                        AttackType                  Target_type  \
# 0                   Assassination  Private Citizens & Property
# 1     Hostage Taking (Kidnapping)      Government (Diplomatic)
# 2                   Assassination          Journalists & Media
# 3               Bombing/Explosion      Government (Diplomatic)
# 4  Facility/Infrastructure Attack      Government (Diplomatic)
#
#                                 Group  Killed
# 0                              MANO-D     1.0
# 1  23rd of September Communist League     0.0
# 2                             Unknown     1.0
# 3                             Unknown     NaN
# 4                             Unknown     NaN

# %%
print("Total columns present in dataset",df.columns)

df.head()
# Out:
# Total columns present in dataset Index(['Year', 'Country', 'Region', 'city', 'AttackType', 'Target_type',
#        'Group', 'Killed'],
#       dtype='object')
#    Year             Country                       Region           city  \
# 0  1970  Dominican Republic  Central America & Caribbean  Santo Domingo
# 1  1970              Mexico                North America    Mexico city
# 2  1970         Philippines               Southeast Asia        Unknown
# 3  1970              Greece               Western Europe         Athens
# 4  1970               Japan                    East Asia        Fukouka
#
#                        AttackType                  Target_type  \
# 0                   Assassination  Private Citizens & Property
# 1     Hostage Taking (Kidnapping)      Government (Diplomatic)
# 2                   Assassination          Journalists & Media
# 3               Bombing/Explosion      Government (Diplomatic)
# 4  Facility/Infrastructure Attack      Government (Diplomatic)
#
#                                 Group  Killed
# 0                              MANO-D     1.0
# 1  23rd of September Communist League     0.0
# 2                             Unknown     1.0
# 3                             Unknown     NaN
# 4                             Unknown     NaN

# %%
df.isnull().sum()
# Out:
# Year              0
# Country           0
# Region            0
# city            430
# AttackType        0
# Target_type       0
# Group             1
# Killed         6516
# dtype: int64

# %%
df=df.dropna()

# %%
df.isnull().sum()
# Out:
# Year           0
# Country        0
# Region         0
# city           0
# AttackType     0
# Target_type    0
# Group          0
# Killed         0
# dtype: int64

# %%
df.sort_values(by=['Killed'],ascending=False).head(10)
# Out:
#        Year                           Country                      Region  \
# 73126  2001                     United States               North America
# 73127  2001                     United States               North America
# 55934  1994                            Rwanda          Sub-Saharan Africa
# 76347  2004                             Nepal                  South Asia
# 6629   1978                              Iran  Middle East & North Africa
# 90401  2009  Democratic Republic of the Congo          Sub-Saharan Africa
# 31595  1987                        Mozambique          Sub-Saharan Africa
# 62468  1996                           Burundi          Sub-Saharan Africa
# 76953  2004                            Russia              Eastern Europe
# 25532  1985                            Canada               North America
#
#                    city                           AttackType  \
# 73126     New York City                            Hijacking
# 73127     New York City                            Hijacking
# 55934            Gikoro                        Armed Assault
# 76347  Dhading district                        Armed Assault
# 6629             Abadan       Facility/Infrastructure Attack
# 90401              Tora       Facility/Infrastructure Attack
# 31595           Homoine                        Armed Assault
# 62468           Kivyuka                              Unknown
# 76953            Beslan  Hostage Taking (Barricade Incident)
# 25532           Toronto                    Bombing/Explosion
#
#                           Target_type  \
# 73126     Private Citizens & Property
# 73127     Private Citizens & Property
# 55934     Private Citizens & Property
# 76347            Government (General)
# 6629                         Business
# 90401  Religious Figures/Institutions
# 31595     Private Citizens & Property
# 62468     Private Citizens & Property
# 76953         Educational Institution
# 25532             Airports & Aircraft
#
#                                                    Group  Killed
# 73126                                           Al-Qaida  1384.0
# 73127                                           Al-Qaida  1383.0
# 55934                                    Hutu extremists  1180.0
# 76347           Communist Party of Nepal- Maoist (CPN-M)   518.0
# 6629                             Mujahedin-e Khalq (MEK)   422.0
# 90401                       Lord's Resistance Army (LRA)   400.0
# 31595      Mozambique National Resistance Movement (MNR)   388.0
# 62468                                   Tutsi extremists   375.0
# 76953  Riyadus-Salikhin Reconnaissance and Sabotage B...   344.0
# 25532                                    Sikh Extremists   329.0

# %%
year_attacks = df.groupby('Year').size().reset_index(name='count')

# %%
sns.lineplot(x='Year', y='count', data=year_attacks, color='red')
plt.xlabel('Year')
plt.ylabel('Number of Attacks')
plt.title("Terrorism Attacks Trends ")
plt.show()

# %%
plt.subplots(figsize=(30,10))
sns.countplot(x='Year', data=df,ec='black')
plt.xticks(rotation=90)
plt.xlabel("Year",fontsize=20)
plt.ylabel('Count',fontsize=20)
plt.grid(True)
plt.show()

# %%
df.Year
# Out:
# 0         1970
# 1         1970
# 2         1970
# 5         1970
# 6         1970
#           ...
# 103321    2011
# 103322    2011
# 103323    2011
# 103324    2011
# 103325    2011
# Name: Year, Length: 96381, dtype: int64

# %%
df.Region
# Out:
# 0         Central America & Caribbean
# 1                       North America
# 2                      Southeast Asia
# 5                       North America
# 6                       South America
#                      ...
# 103321                     South Asia
# 103322                     South Asia
# 103323     Middle East & North Africa
# 103324                     South Asia
# 103325                 Southeast Asia
# Name: Region, Length: 96381, dtype: object

# %%
pd.crosstab(df.Year,df.Region).plot(kind='area',figsize=(20,6))
plt.xlabel('Year')
plt.ylabel('Count')
plt.title('Terrorist Activities by Region in a Year')
plt.grid(True)
plt.show()

# %%
r_type=df.Region.value_counts().to_frame().reset_index()
print(r_type)
r_type.columns=['region_name','count']
# Out:
#                           index  Region
# 0    Middle East & North Africa   19298
# 1                    South Asia   18976
# 2                 South America   16188
# 3                Western Europe   14142
# 4   Central America & Caribbean    7993
# 5            Sub-Saharan Africa    6629
# 6                Southeast Asia    5940
# 7                 North America    3018
# 8                Eastern Europe    2814
# 9                     East Asia     662
# 10                 Central Asia     491
# 11        Australasia & Oceania     230

# %%
az=sns.barplot(y='region_name',x='count',data=r_type,palette='flare',ec='black')
plt.grid(True)
plt.title("Number of Total Attacks in Each Region")
plt.ylabel('Region')
plt.xlabel('Number of attacks')

plt.show()

# %%
top_10_country=df.Country.value_counts()[:10].to_frame().reset_index()
top_10_country
# Out:
#             index  Country
# 0            Iraq     7295
# 1        Colombia     6981
# 2           India     6740
# 3            Peru     5409
# 4        Pakistan     5196
# 5  United Kingdom     4427
# 6     El Salvador     3939
# 7     Philippines     3198
# 8           Spain     2938
# 9       Sri Lanka     2885

# %%
top_10_country.columns=['country_name','count']

# %%
top_10_country
# Out:
#      country_name  count
# 0            Iraq   7295
# 1        Colombia   6981
# 2           India   6740
# 3            Peru   5409
# 4        Pakistan   5196
# 5  United Kingdom   4427
# 6     El Salvador   3939
# 7     Philippines   3198
# 8           Spain   2938
# 9       Sri Lanka   2885

# %%
plt.figure(figsize=(15,5))
ay=sns.barplot(data=top_10_country,x='country_name',y='count',ec='red',lw=1)
plt.grid(True)
plt.title('Top 10 Countries with most Attacks',fontsize=30)
plt.xlabel('Country',fontsize=20)
plt.ylabel('Count',fontsize=20)

for p in ay.patches:
    ay.annotate(format(p.get_height(), '.2f'),
                (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center',
                xytext=(0, 10), textcoords='offset points')

plt.show()

# %%
top_10_country_kill=df.groupby('Country').Killed.sum().to_frame().reset_index().sort_values('Killed',ascending=False)[0:10]
top_10_country_kill
# Out:
#          Country   Killed
# 81          Iraq  26773.0
# 77         India  16737.0
# 163    Sri Lanka  15523.0
# 33      Colombia  13998.0
# 136         Peru  12726.0
# 50   El Salvador  12053.0
# 131     Pakistan  11640.0
# 2        Algeria  10849.0
# 125    Nicaragua  10593.0
# 0    Afghanistan   7519.0

# %%
plt.figure(figsize=(10,5))
ax = sns.barplot(y='Killed',x='Country',data=top_10_country_kill,ec='black')
plt.xlabel('Name of the Country')
plt.ylabel('Number of people Killed')
plt.grid(True)
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.2f'),
                (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center',
                xytext=(0, 10), textcoords='offset points')

plt.show()

# %%
df.Region.value_counts()
# Out:
# Middle East & North Africa     19298
# South Asia                     18976
# South America                  16188
# Western Europe                 14142
# Central America & Caribbean     7993
# Sub-Saharan Africa              6629
# Southeast Asia                  5940
# North America                   3018
# Eastern Europe                  2814
# East Asia                        662
# Central Asia                     491
# Australasia & Oceania            230
# Name: Region, dtype: int64

# %%
data_south_asia=df[df['Region']=='South Asia']
data_south_asia.head()
# Out:
#       Year      Country      Region       city         AttackType  \
# 585   1970     Pakistan  South Asia    Karachi      Assassination
# 1186  1972        India  South Asia  New Delhi          Hijacking
# 1863  1973  Afghanistan  South Asia      Kabul            Unknown
# 2217  1974     Pakistan  South Asia    Karachi  Bombing/Explosion
# 2705  1974     Pakistan  South Asia   Peshawar  Bombing/Explosion
#
#                   Target_type              Group  Killed
# 585   Government (Diplomatic)            Unknown     4.0
# 1186      Airports & Aircraft       Palestinians     0.0
# 1863      Airports & Aircraft     Black December     0.0
# 2217                 Maritime  Muslim Guerrillas     0.0
# 2705  Government (Diplomatic)            Unknown     0.0

# %%
data_south_asia.Country.count()
data_ind_pak_afg=data_south_asia

# %%
data_ind_pak_afg = data_ind_pak_afg[(data_ind_pak_afg.Country=='Pakistan') | (data_ind_pak_afg.Country=='Afghanistan') | (data_ind_pak_afg.Country=='India')]
data_ind_pak_afg.head()
# Out:
#       Year      Country      Region       city         AttackType  \
# 585   1970     Pakistan  South Asia    Karachi      Assassination
# 1186  1972        India  South Asia  New Delhi          Hijacking
# 1863  1973  Afghanistan  South Asia      Kabul            Unknown
# 2217  1974     Pakistan  South Asia    Karachi  Bombing/Explosion
# 2705  1974     Pakistan  South Asia   Peshawar  Bombing/Explosion
#
#                   Target_type              Group  Killed
# 585   Government (Diplomatic)            Unknown     4.0
# 1186      Airports & Aircraft       Palestinians     0.0
# 1863      Airports & Aircraft     Black December     0.0
# 2217                 Maritime  Muslim Guerrillas     0.0
# 2705  Government (Diplomatic)            Unknown     0.0

# %%
data_ind_pak_afg_count = (data_ind_pak_afg.groupby(['Country','Year'])['Killed'].size()).reset_index()
data_ind_pak_afg_count
# Out:
#         Country  Year  Killed
# 0   Afghanistan  1973       1
# 1   Afghanistan  1979       3
# 2   Afghanistan  1987       1
# 3   Afghanistan  1988      11
# 4   Afghanistan  1989      10
# ..          ...   ...     ...
# 94     Pakistan  2007     253
# 95     Pakistan  2008     561
# 96     Pakistan  2009     660
# 97     Pakistan  2010     712
# 98     Pakistan  2011     747
#
# [99 rows x 3 columns]

# %%
fig = plt.figure(figsize=(16,5))
sns.lineplot(data = data_ind_pak_afg_count,x = 'Year',y = 'Killed',hue = 'Country',style = 'Country',palette='magma_r',markers=True, dashes=False)
plt.title("Total People Kiled across the Years in Pakistan, Afghanistan and India",fontsize=20)
plt.grid(True)
plt.xlabel('Name of the Year',fontsize=15)
plt.ylabel('Number of People Killed',fontsize=15)
plt.show()

# %%
df['Target_type'].value_counts().head()
# Out:
# Private Citizens & Property    21824
# Business                       13806
# Government (General)           13537
# Police                         11713
# Military                       10777
# Name: Target_type, dtype: int64

# %%
list(df['Target_type'].value_counts().head())
# Out:
# [21824, 13806, 13537, 11713, 10777]

# %%
list(df['Target_type'].value_counts().head().keys())
# Out:
# ['Private Citizens & Property',
#  'Business',
#  'Government (General)',
#  'Police',
#  'Military']

# %%
plt.figure(figsize=(10,5))
col=['red','yellow','green','black','pink','orange']
plt.bar(list(df['Target_type'].value_counts().head().keys()),list(df['Target_type'].value_counts().head()),color=col,ec='black')
plt.grid(True)
plt.xlabel('Name of the Target',fontsize=11)
plt.ylabel('Number of Attacks',fontsize=11)


plt.show()

# %%
year=(df.groupby(['Year'])['Killed'].size()).reset_index()
year
# Out:
#     Year  Killed
# 0   1970     609
# 1   1971     407
# 2   1972     524
# 3   1973     424
# 4   1974     523
# 5   1975     587
# 6   1976     814
# 7   1977    1189
# 8   1978    1373
# 9   1979    2257
# 10  1980    2211
# 11  1981    1928
# 12  1982    1742
# 13  1983    1974
# 14  1984    2805
# 15  1985    2475
# 16  1986    2481
# 17  1987    3089
# 18  1988    3689
# 19  1989    4290
# 20  1990    3881
# 21  1991    4579
# 22  1992    5048
# 23  1994    3368
# 24  1995    3076
# 25  1996    3001
# 26  1997    3130
# 27  1998     871
# 28  1999    1345
# 29  2000    1757
# 30  2001    1885
# 31  2002    1321
# 32  2003    1258
# 33  2004    1151
# 34  2005    1999
# 35  2006    2619
# 36  2007    3171
# 37  2008    4649
# 38  2009    4551
# 39  2010    4757
# 40  2011    3573

# %%
year=year.sort_values(by=['Killed'],ascending=False).head()
year
# Out:
#     Year  Killed
# 22  1992    5048
# 39  2010    4757
# 37  2008    4649
# 21  1991    4579
# 38  2009    4551

# %%
list(year['Year'])
# Out:
# [1992, 2010, 2008, 1991, 2009]

# %%
plt.figure(figsize=(10,5))
color=['red','orange','pink','blue','yellow']
plt.bar(list(year['Year']),list(year['Killed']),color=color,ec='black')
plt.grid(True)
plt.xlabel('Name of the Year')
plt.ylabel('Number of People Killed')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.subplots(figsize=(15, 6))
sns.countplot(x='AttackType', data=df, palette='inferno', order=df['AttackType'].value_counts().index)
plt.xticks(rotation=90)
plt.title('Attacking Methods by Terrorists')
plt.show()
